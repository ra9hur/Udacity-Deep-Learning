# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5241, 3081, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'a', 'originated', 'originated', 'as', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-7-01669d5c739a>:4 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.998988
# Nearest to for: james, undue, casein, microcebus, created, coliseum, lawfully, reinhold,
# Nearest to also: landowners, thornton, tds, nord, idealist, bathroom, kenner, xena,
# Nearest to one: acceptor, erythematosus, loathed, plotinus, brokers, munster, theologians, mysia,
# Nearest to no: trigrams, heath, openness, tiled, lebrun, nernst, saya, diamondbacks,
# Nearest to war: silvia, ventspils, burgoyne, cavers, gettier, pros, netting, edgard,
# Nearest to used: tans, compensating, nighthawk, anxiolytics, benjamin, drinking, deficit, sheffield,
# Nearest to a: marcello, ames, transjordan, minsky, daria, oder, barber, dumpster,
# Nearest to three: chewing, vaishnavism, yerushalmi, col, maastricht, opengl, lithium, exit,
# Nearest to th: gladiatorial, rhenish, blogs, website, heydrich, manzikert, autonomic, dartmoor,
# Nearest to and: nazarbayev, liang, gainesville, horseshoe, capillaries, neared, spraying, cumings,
# Nearest to were: vladivostok, reconciled, romania, polluted, pad, punctuation, splitflag, donne,
# Nearest to the: jena, jalalabad, leather, bellows, zhao, wondered, liberians, composite,
# Nearest to than: provision, bowhunting, weizmann, sabers, killing, find, bootstrapping, birth,
# Nearest to zero: churning, marriages, jamie, subsidized, loathing, machinery, words, resisting,
# Nearest to they: mottled, livius, youssef, baccalaureate, haiku, mla, galveston, carthaginian,
# Nearest to system: rcn, again, provable, excel, gasp, gelatin, stipend, preferring,
# Average loss at step 2000: 4.360644
# Average loss at step 4000: 3.864531
# Average loss at step 6000: 3.789613
# Average loss at step 8000: 3.687428
# Average loss at step 10000: 3.621244
# Nearest to for: with, pong, registry, in, meridians, of, partements, borrower,
# Nearest to also: not, often, quintus, seize, sieges, magnify, which, there,
# Nearest to one: two, three, four, seven, five, six, eight, kpd,
# Nearest to no: nernst, it, angilbert, libri, trigrams, stoic, plumbing, equalizer,
# Nearest to war: silvia, march, keller, burgoyne, ventspils, edgard, gettier, radiative,
# Nearest to used: iast, known, crewed, deficit, designed, commuters, euboea, fortran,
# Nearest to a: the, inquiries, this, sefer, marque, gon, stevenson, marquess,
# Nearest to three: four, seven, five, six, eight, two, zero, nine,
# Nearest to th: rhenish, three, website, two, heydrich, mounts, manzikert, carmel,
# Nearest to and: or, s, pigot, of, khoisan, boiling, homogenized, in,
# Nearest to were: are, was, have, reconciled, wernicke, vladivostok, is, by,
# Nearest to the: a, its, this, his, their, an, optimizations, inflected,
# Nearest to than: or, vorbis, weizmann, sabers, birth, provision, lai, bowhunting,
# Nearest to zero: seven, nine, six, eight, five, four, three, two,
# Nearest to they: he, we, there, who, it, mla, abhidhamma, abt,
# Nearest to system: again, rcn, stipend, implicated, gelatin, welt, excel, bulldogs,
# Average loss at step 12000: 3.603532
# Average loss at step 14000: 3.568760
# Average loss at step 16000: 3.409316
# Average loss at step 18000: 3.457945
# Average loss at step 20000: 3.541615
# Nearest to for: with, and, in, under, from, of, through, ipc,
# Nearest to also: which, often, not, who, then, still, quintus, now,
# Nearest to one: four, two, three, seven, six, eight, five, nine,
# Nearest to no: any, nernst, a, it, gravity, there, majestic, this,
# Nearest to war: silvia, march, keller, busting, pros, caribbean, gettier, rights,
# Nearest to used: known, found, designed, granting, fortran, defined, machinery, possible,
# Nearest to a: any, this, spratly, no, outstanding, crystallize, another, very,
# Nearest to three: six, four, five, two, seven, eight, nine, one,
# Nearest to th: rhenish, manzikert, website, heydrich, perturbations, blogs, circling, thickly,
# Nearest to and: or, but, hae, in, khoisan, for, malraux, from,
# Nearest to were: are, was, had, have, be, is, parentheses, by,
# Nearest to the: their, its, this, his, evaporate, concealment, these, an,
# Nearest to than: or, vorbis, mccain, buttons, provision, weizmann, eliminate, slovak,
# Nearest to zero: five, six, seven, four, eight, three, nine, two,
# Nearest to they: he, we, there, it, who, you, ahura, not,
# Nearest to system: implicated, again, subjective, gelatin, testifies, rcn, stipend, alcor,
# Average loss at step 22000: 3.501622
# Average loss at step 24000: 3.491364
# Average loss at step 26000: 3.483217
# Average loss at step 28000: 3.481338
# Average loss at step 30000: 3.503382
# Nearest to for: when, of, against, in, among, ipc, after, with,
# Nearest to also: now, often, who, still, sometimes, which, there, below,
# Nearest to one: two, seven, four, six, eight, five, three, nine,
# Nearest to no: any, a, nernst, it, there, gravity, usually, angilbert,
# Nearest to war: march, silvia, keller, gettier, transmit, netting, friends, caribbean,
# Nearest to used: found, known, designed, defined, possible, machinery, drinking, granting,
# Nearest to a: any, the, no, too, edsger, kidnapped, fortieth, tally,
# Nearest to three: four, five, seven, eight, two, six, nine, zero,
# Nearest to th: three, six, rhenish, circling, eight, perturbations, five, seven,
# Nearest to and: or, but, in, against, of, who, american, however,
# Nearest to were: are, was, have, had, those, by, parentheses, been,
# Nearest to the: their, its, his, some, a, yakov, evaporate, beekeepers,
# Nearest to than: or, much, vorbis, eliminate, parts, mccain, sprache, slovak,
# Nearest to zero: five, seven, six, eight, four, three, nine, two,
# Nearest to they: we, there, he, who, these, you, it, not,
# Nearest to system: systems, gelatin, unfilled, subjective, implicated, comet, tisdall, testifies,
# Average loss at step 32000: 3.504435
# Average loss at step 34000: 3.492520
# Average loss at step 36000: 3.452841
# Average loss at step 38000: 3.302730
# Average loss at step 40000: 3.429794
# Nearest to for: when, if, regicide, of, seizures, in, borrower, gwen,
# Nearest to also: often, which, now, still, there, sometimes, usually, below,
# Nearest to one: seven, eight, four, two, six, three, five, nine,
# Nearest to no: any, often, nernst, usually, there, appealed, a, angilbert,
# Nearest to war: silvia, march, keller, gettier, guyana, caribbean, transmit, gadgets,
# Nearest to used: found, known, designed, seen, considered, defined, possible, mentioned,
# Nearest to a: the, another, any, gloucestershire, flaminius, nolo, this, fincher,
# Nearest to three: four, five, six, two, seven, eight, nine, one,
# Nearest to th: rhenish, circling, seven, perturbations, rd, three, bits, eight,
# Nearest to and: but, or, fourteenth, though, however, while, hygiene, minstrels,
# Nearest to were: are, have, was, had, those, been, these, be,
# Nearest to the: their, its, this, a, his, walked, any, some,
# Nearest to than: or, much, parts, eliminate, sprache, ninety, vorbis, slovak,
# Nearest to zero: five, seven, nine, eight, six, three, four, million,
# Nearest to they: we, he, there, you, it, these, who, not,
# Nearest to system: systems, subjective, implicated, composes, ebcdic, gelatin, gained, choice,
# Average loss at step 42000: 3.433939
# Average loss at step 44000: 3.451499
# Average loss at step 46000: 3.450156
# Average loss at step 48000: 3.356268
# Average loss at step 50000: 3.383123
# Nearest to for: against, regicide, exponential, while, motorized, gwen, equity, previous,
# Nearest to also: now, often, which, still, deco, sometimes, mprp, then,
# Nearest to one: two, six, four, eight, seven, three, five, nine,
# Nearest to no: any, appealed, pictish, a, suction, hallucinogen, pigmented, little,
# Nearest to war: silvia, march, keller, gettier, caribbean, gadgets, guyana, arbiter,
# Nearest to used: known, found, seen, designed, possible, considered, necessary, defined,
# Nearest to a: the, any, another, stevenson, inoffensive, no, engrams, flaminius,
# Nearest to three: four, six, seven, five, eight, two, nine, zero,
# Nearest to th: five, one, three, orchestrated, four, six, circling, rhenish,
# Nearest to and: or, but, than, hae, lito, while, oblivious, s,
# Nearest to were: are, was, have, be, had, being, those, been,
# Nearest to the: its, their, this, his, dvo, a, any, kai,
# Nearest to than: or, much, and, strangle, twigs, sprache, mccain, parts,
# Nearest to zero: five, seven, eight, six, four, nine, three, two,
# Nearest to they: we, there, he, it, you, she, who, never,
# Nearest to system: systems, subjective, composes, wis, interbreeding, implicated, ebcdic, deterioration,
# Average loss at step 52000: 3.433966
# Average loss at step 54000: 3.428793
# Average loss at step 56000: 3.436974
# Average loss at step 58000: 3.395378
# Average loss at step 60000: 3.398174
# Nearest to for: without, including, reductionist, geographic, of, granting, deianira, exponential,
# Nearest to also: now, often, still, sometimes, mestizos, deco, which, typically,
# Nearest to one: eight, six, two, four, seven, nine, three, five,
# Nearest to no: any, appealed, little, dil, hallucinogen, gunman, pigmented, albret,
# Nearest to war: silvia, march, keller, gadgets, maitreya, friends, yat, gettier,
# Nearest to used: known, designed, found, seen, defined, necessary, called, considered,
# Nearest to a: any, another, the, stevenson, this, libri, every, aut,
# Nearest to three: five, four, six, eight, two, seven, nine, one,
# Nearest to th: eight, four, six, orchestrated, five, nd, seven, circling,
# Nearest to and: or, but, including, while, than, gainesville, although, luminosity,
# Nearest to were: are, was, have, had, those, been, be, including,
# Nearest to the: their, its, cookies, this, any, a, each, his,
# Nearest to than: or, much, but, far, and, sprache, ninety, dervish,
# Nearest to zero: five, seven, four, eight, six, nine, three, two,
# Nearest to they: we, there, you, he, it, not, she, who,
# Nearest to system: systems, wis, composes, choice, subjective, gained, isca, organize,
# Average loss at step 62000: 3.242320
# Average loss at step 64000: 3.261326
# Average loss at step 66000: 3.402311
# Average loss at step 68000: 3.392141
# Average loss at step 70000: 3.362964
# Nearest to for: including, of, in, geographic, without, schneier, after, if,
# Nearest to also: now, often, still, which, sometimes, usually, deco, strongly,
# Nearest to one: two, six, seven, four, eight, five, three, nine,
# Nearest to no: any, pigmented, little, hallucinogen, there, gunman, pie, genocidal,
# Nearest to war: silvia, keller, march, wyatt, gadgets, maitreya, elysium, danann,
# Nearest to used: known, designed, found, seen, defined, necessary, available, possible,
# Nearest to a: another, the, stevenson, any, libri, flaminius, rollout, unranked,
# Nearest to three: four, two, six, five, seven, eight, nine, one,
# Nearest to th: third, rd, bce, orchestrated, nd, st, ce, circling,
# Nearest to and: or, but, produce, hae, of, ethos, than, philistines,
# Nearest to were: are, have, was, had, be, been, chaff, include,
# Nearest to the: their, its, any, this, a, some, our, whose,
# Nearest to than: or, much, dervish, sprache, but, far, and, while,
# Nearest to zero: five, eight, six, seven, four, nine, three, million,
# Nearest to they: we, you, he, there, it, she, then, woodcut,
# Nearest to system: systems, program, wis, ebcdic, desegregation, mechanically, subjective, isca,
# Average loss at step 72000: 3.370019
# Average loss at step 74000: 3.346290
# Average loss at step 76000: 3.309091
# Average loss at step 78000: 3.353501
# Average loss at step 80000: 3.381593
# Nearest to for: provisional, casein, gwen, monkey, without, aleutians, bowels, equity,
# Nearest to also: now, often, still, sometimes, which, usually, mprp, below,
# Nearest to one: six, seven, two, eight, five, four, three, minimax,
# Nearest to no: any, little, hallucinogen, gunman, apap, pigmented, aged, anselm,
# Nearest to war: silvia, march, keller, maitreya, wyatt, wars, transmit, callisto,
# Nearest to used: known, found, designed, seen, available, necessary, defined, referred,
# Nearest to a: another, the, aerials, engrams, every, veitch, marcello, inoffensive,
# Nearest to three: five, six, four, seven, two, eight, nine, zero,
# Nearest to th: orchestrated, three, seven, bce, rd, ce, fourth, circling,
# Nearest to and: or, but, feyerabend, generalize, including, while, bunyan, spasms,
# Nearest to were: are, had, have, was, include, chaff, disrupts, been,
# Nearest to the: its, their, his, a, this, those, concealment, our,
# Nearest to than: or, much, but, far, sprache, dervish, mccain, screened,
# Nearest to zero: seven, five, six, eight, four, nine, three, two,
# Nearest to they: we, he, there, you, she, it, these, who,
# Nearest to system: systems, program, wis, suzhou, multiprocessing, subjective, desegregation, ebcdic,
# Average loss at step 82000: 3.405546
# Average loss at step 84000: 3.408524
# Average loss at step 86000: 3.390058
# Average loss at step 88000: 3.351482
# Average loss at step 90000: 3.362654
# Nearest to for: including, while, against, after, of, amaterasu, during, when,
# Nearest to also: now, often, still, mprp, sometimes, which, absolutist, woolly,
# Nearest to one: seven, four, eight, two, six, five, three, nine,
# Nearest to no: any, little, pigmented, only, gunman, there, mule, aged,
# Nearest to war: silvia, during, march, keller, sympathies, wyatt, guyana, homeland,
# Nearest to used: designed, known, seen, necessary, referred, found, considered, available,
# Nearest to a: any, every, another, rollout, engrams, aerials, the, stevenson,
# Nearest to three: four, five, two, eight, seven, six, nine, one,
# Nearest to th: seven, orchestrated, nd, nine, ce, rd, bce, twentieth,
# Nearest to and: or, but, while, including, aac, ectopic, in, faithfully,
# Nearest to were: are, had, was, have, while, although, these, disquiet,
# Nearest to the: its, their, his, any, this, filming, a, undercut,
# Nearest to than: much, dervish, sprache, or, far, slightly, twigs, cornet,
# Nearest to zero: seven, six, eight, nine, five, four, three, u,
# Nearest to they: we, he, there, you, she, it, these, cautions,
# Nearest to system: systems, program, wis, zurich, suzhou, method, ebcdic, desegregation,
# Average loss at step 92000: 3.393113
# Average loss at step 94000: 3.256799
# Average loss at step 96000: 3.356731
# Average loss at step 98000: 3.238714
# Average loss at step 100000: 3.356674
# Nearest to for: including, after, when, without, before, if, apec, during,
# Nearest to also: now, still, often, never, actually, sometimes, mprp, generally,
# Nearest to one: two, seven, eight, five, four, six, nine, three,
# Nearest to no: little, any, pigmented, gunman, hallucinogen, genocidal, mule, true,
# Nearest to war: silvia, march, keller, gulfs, guyana, homeland, sympathies, ballads,
# Nearest to used: designed, necessary, known, found, seen, referred, considered, defined,
# Nearest to a: another, the, any, flaminius, grown, obi, engrams, aerials,
# Nearest to three: five, four, two, seven, six, eight, nine, zero,
# Nearest to th: nd, rd, third, bce, orchestrated, twentieth, fourth, glaser,
# Nearest to and: or, but, like, while, although, bunyan, when, aac,
# Nearest to were: are, was, these, have, those, had, disquiet, solaris,
# Nearest to the: his, their, our, a, its, your, each, lakshadweep,
# Nearest to than: or, much, slightly, dervish, sprache, dekker, pandemics, far,
# Nearest to zero: five, eight, four, seven, six, nine, three, million,
# Nearest to they: we, there, he, you, she, it, these, woodcut,
# Nearest to system: systems, program, multiprocessing, wis, method, jehoash, ebcdic, deregulated,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# -------------- Function to generate a training batch for the CBOW model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        target = skip_window    # target label at the center of the buffer
        j1 = 0
        for j in range(span):
            if j != target:
                batch[i, j1] = buffer[j]
                j1 += 1
        labels[i, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels


print('data: ', [reverse_dictionary[di] for di in data[:8]])
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']

for num_skips, skip_window in [(2, 1)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for _,bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data:  ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']

# %%
# -------------- Train a CBOW model.
batch_size = 128
embedding_size = 128    # Dimension of the embedding vector
skip_window = 1         # How many words to consider left and right
num_skips = 2           # How many times to reuse an input to generate a label
# We pick a random validation set to sample nearest neighbors.
# Here we limit the validation samples to the words that have a low numeric ID
# which by construction, are also most frequent
valid_size = 16         # Random set of words to evaluate similarity on.
valid_window = 100      # Only pick dev samples in the head of the distribution
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64        # Number of negative examples to sample

# %%
graph = tf.Graph()

# Ops and variables pinned to the CPU because of missing GPU implementation
with graph.as_default(), tf.device('/cpu:0'):
    
    # Input data
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size,2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size,1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model
    # embed = tf.nn.embedding_lookup(embeddings, train_dataset[:,:1])
    embed_context0 = tf.nn.embedding_lookup(embeddings, train_dataset[:,0])
    embed_context1 = tf.nn.embedding_lookup(embeddings, train_dataset[:,1])
    embed = embed_context0 + embed_context1

    # Compute the softmax loss, using a sample of the negative labels
    softmax_error = tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed, train_labels, num_sampled, vocabulary_size)
    loss = tf.reduce_mean(softmax_error)

    # noise-contrastive estimation (NCE) loss ----> refer below
    
    # Optimizer
    optimizer = tf.train.AdagradOptimizer(0.9)
    train_step = optimizer.minimize(loss)
    
    # Compute similarity between minibatch examples and all embeddings
    # We use the cosine distance
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
step_list = list()
cbow_loss_list = list()

# ======== Launch the graph ==========
with tf.Session(graph=graph) as session:
    init = tf.global_variables_initializer()
    session.run(init)
    print("Initialized")
    
    average_loss = 0
    
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        
        _, l = session.run([train_step, loss], feed_dict=feed_dict)
        
        average_loss += l
        
        if (step % 2000) == 0:
            if step > 0:
                # estimate of the loss over the last 2000 batches
                average_loss = average_loss / 2000
            print('Average loss at step %d: %f' % (step, average_loss))
            cbow_loss_list.append(average_loss)
            step_list.append(step)
            
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if (step % 10000) == 0:
            sim = similarity.eval()
            
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8   # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % (valid_word)
                
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
                
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.660240
# Nearest to eight: disagrees, obligate, conspicuous, pubic, antares, canonization, cloned, opencourseware,
# Nearest to his: commit, relations, shooting, supervise, covenant, seminole, rgya, nfs,
# Nearest to years: accessibility, flamebait, porvoo, font, sci, marks, blish, alley,
# Nearest to in: colby, risk, punctured, rosenthal, neko, sweating, laminar, andropov,
# Nearest to and: len, sour, atomism, sarabande, bacteriology, font, canard, yd,
# Nearest to also: loci, reviewing, troops, clockless, pharmacy, alfonso, eukaryotic, hesitate,
# Nearest to most: warriors, allafrica, cartographer, wrongful, wireless, aluminum, calibrated, pathologic,
# Nearest to it: gunship, mla, fifth, spores, underestimated, carcasses, poured, macos,
# Nearest to has: ferro, canines, enveloped, montesquieu, nibelungenlied, ct, wavefunction, schott,
# Nearest to i: decomposers, overbeck, volcanic, xiv, beachcomber, citro, portal, depopulated,
# Nearest to that: eisenman, contemplated, conducive, ndebele, moldovans, tal, update, decade,
# Nearest to for: signified, overseer, conjunctions, episcopalian, liege, lobbyist, baltasar, portraiture,
# Nearest to is: fiqh, hokkaido, barbarians, bouchard, dafoe, txt, ita, laplace,
# Nearest to can: headless, bugtraq, hermon, prohibitive, cephalopods, synthetically, bruises, harrington,
# Nearest to war: avoided, enemy, conspired, aching, countered, deluxe, enfield, penalized,
# Nearest to all: tuner, finno, entitlement, girlfriend, css, relator, tenderness, junkers,
# Average loss at step 2000: 3.997014
# Average loss at step 4000: 3.499617
# Average loss at step 6000: 3.412841
# Average loss at step 8000: 3.354151
# Average loss at step 10000: 3.192618
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to his: her, their, the, its, puma, opioid, module, curving,
# Nearest to years: accessibility, spindle, days, flamebait, argue, briefly, texture, infibulation,
# Nearest to in: on, at, during, of, gabab, curtailing, colby, hospitality,
# Nearest to and: or, including, showroom, ignacio, consecrations, txt, alkalis, trios,
# Nearest to also: still, which, loci, often, now, not, lacks, rent,
# Nearest to most: marcellus, pathologic, some, wrapped, freedman, warriors, aegisthus, kiss,
# Nearest to it: he, this, there, she, unjustly, quantized, maecenas, esdras,
# Nearest to has: had, have, was, is, extracellular, enveloped, overarching, ius,
# Nearest to i: they, asimov, depopulated, pais, we, tongues, remembers, aerosol,
# Nearest to that: which, this, however, plundering, seizing, it, keats, stiller,
# Nearest to for: grained, flavoring, subtended, gwadar, yad, abandon, leaps, hybridized,
# Nearest to is: was, are, has, became, bates, reuben, sef, fibs,
# Nearest to can: will, would, may, must, could, should, thugs, alla,
# Nearest to war: avoided, costing, annex, penalized, conspired, kosovo, rockall, tort,
# Nearest to all: entitlement, many, tuner, rance, processions, these, defensively, some,
# Average loss at step 12000: 3.234141
# Average loss at step 14000: 3.190377
# Average loss at step 16000: 3.209510
# Average loss at step 18000: 3.023771
# Average loss at step 20000: 2.887104
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to his: her, their, its, my, the, derleth, s, announcers,
# Nearest to years: days, times, months, year, spindle, others, argue, saul,
# Nearest to in: during, at, of, on, starfish, within, near, with,
# Nearest to and: or, including, but, consecrations, pro, in, inductees, kidnapping,
# Nearest to also: often, still, which, now, always, usually, who, frequently,
# Nearest to most: more, some, many, eastern, freedman, less, katsuhiro, kiss,
# Nearest to it: he, there, she, this, they, what, quantized, unjustly,
# Nearest to has: had, have, is, was, having, extracellular, enveloped, relinquish,
# Nearest to i: we, you, asimov, they, tongues, ii, tout, depopulated,
# Nearest to that: which, however, knuth, keats, seizing, stiller, where, kuril,
# Nearest to for: of, repository, after, unbearable, when, grained, yad, hybridized,
# Nearest to is: was, are, has, be, includes, alshehhi, became, had,
# Nearest to can: will, would, may, could, must, should, cannot, might,
# Nearest to war: avoided, costing, annex, salts, tort, intellectual, meriwether, intervarsity,
# Nearest to all: some, quadrant, many, tenderness, entitlement, both, rance, rome,
# Average loss at step 22000: 2.962291
# Average loss at step 24000: 3.089349
# Average loss at step 26000: 2.946787
# Average loss at step 28000: 3.005356
# Average loss at step 30000: 3.050882
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to his: her, their, its, my, the, your, curving, derleth,
# Nearest to years: days, months, times, year, spindle, weeks, others, minutes,
# Nearest to in: during, within, throughout, at, on, with, sceptical, from,
# Nearest to and: or, but, including, relator, who, chiropractors, instructors, andreas,
# Nearest to also: still, now, often, always, sometimes, usually, which, frequently,
# Nearest to most: more, some, many, less, nameless, katsuhiro, aegisthus, unconstitutional,
# Nearest to it: he, she, there, this, they, which, what, unjustly,
# Nearest to has: had, have, is, was, extracellular, relinquish, overrun, provides,
# Nearest to i: we, they, ii, you, asimov, tout, detergent, tongues,
# Nearest to that: which, however, what, seizing, knuth, kuril, zx, ndebele,
# Nearest to for: mib, if, after, against, while, mythological, grained, flavoring,
# Nearest to is: was, has, are, includes, became, does, sef, means,
# Nearest to can: may, will, could, would, must, should, cannot, might,
# Nearest to war: costing, avoided, annex, tort, intellectual, abolition, salts, meriwether,
# Nearest to all: both, many, some, entitlement, tenderness, rance, quadrant, various,
# Average loss at step 32000: 2.942112
# Average loss at step 34000: 2.931344
# Average loss at step 36000: 2.922401
# Average loss at step 38000: 2.855367
# Average loss at step 40000: 2.863392
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to his: her, their, my, its, your, the, derleth, whose,
# Nearest to years: days, months, times, year, minutes, weeks, centuries, spindle,
# Nearest to in: during, at, within, on, under, near, colby, throughout,
# Nearest to and: or, but, evocative, jammu, including, relator, however, who,
# Nearest to also: still, now, often, always, usually, which, never, traditionally,
# Nearest to most: more, many, some, less, nameless, fulfillment, katsuhiro, gianfranco,
# Nearest to it: he, she, there, this, they, whores, what, often,
# Nearest to has: had, have, is, was, having, extracellular, fibs, grozny,
# Nearest to i: ii, we, you, iii, asimov, cultic, griswold, g,
# Nearest to that: which, what, however, seizing, knuth, where, because, but,
# Nearest to for: while, of, repository, after, mib, without, benoit, during,
# Nearest to is: was, has, are, involves, became, includes, does, contains,
# Nearest to can: may, will, could, would, must, should, cannot, might,
# Nearest to war: costing, annex, avoided, intellectual, tort, salts, abolition, intervarsity,
# Nearest to all: many, both, various, those, several, entitlement, defensively, quadrant,
# Average loss at step 42000: 2.902398
# Average loss at step 44000: 2.904204
# Average loss at step 46000: 2.923815
# Average loss at step 48000: 2.894497
# Average loss at step 50000: 2.768629
# Nearest to eight: nine, seven, six, four, five, zero, three, two,
# Nearest to his: her, their, its, my, your, the, whose, our,
# Nearest to years: days, months, times, year, weeks, minutes, centuries, decades,
# Nearest to in: during, within, at, throughout, gabab, hospitality, of, popolo,
# Nearest to and: or, but, including, while, medgar, evocative, overstated, consecrations,
# Nearest to also: often, still, now, always, usually, which, never, typically,
# Nearest to most: more, less, many, some, among, entre, nameless, kiss,
# Nearest to it: he, she, this, there, they, unjustly, which, what,
# Nearest to has: had, have, is, was, having, extracellular, bracelet, since,
# Nearest to i: we, ii, you, g, iii, they, asimov, recipients,
# Nearest to that: which, what, this, kuril, however, where, because, straus,
# Nearest to for: if, repository, flavoring, when, grained, subtended, while, cadets,
# Nearest to is: was, became, has, are, be, contains, becomes, involves,
# Nearest to can: may, will, could, must, would, should, might, cannot,
# Nearest to war: costing, annex, intellectual, avoided, intervarsity, tort, inconclusive, abolition,
# Nearest to all: both, many, quadrant, none, tuner, disinfectant, several, any,
# Average loss at step 52000: 2.893964
# Average loss at step 54000: 2.859679
# Average loss at step 56000: 2.860760
# Average loss at step 58000: 2.868832
# Average loss at step 60000: 2.854829
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to his: her, their, its, my, your, whose, our, derleth,
# Nearest to years: days, months, times, weeks, year, centuries, minutes, decades,
# Nearest to in: within, during, throughout, until, among, at, lustre, on,
# Nearest to and: or, but, although, medgar, including, kobayashi, pediatrics, breatharian,
# Nearest to also: now, still, often, always, never, sometimes, usually, typically,
# Nearest to most: more, less, many, some, nameless, gianfranco, especially, marcellus,
# Nearest to it: he, she, this, there, they, what, scsi, covariance,
# Nearest to has: had, have, is, was, provides, having, contains, seemed,
# Nearest to i: ii, we, g, you, iii, misalignment, remembers, recipients,
# Nearest to that: which, however, what, knuth, where, eisenman, kuril, seizing,
# Nearest to for: flavoring, lobbyist, grained, cadets, if, against, searched, balloon,
# Nearest to is: was, has, involves, are, sef, becomes, contains, remains,
# Nearest to can: may, could, must, should, will, would, might, cannot,
# Nearest to war: costing, annex, intellectual, intervarsity, convex, avoided, cia, tort,
# Nearest to all: both, some, any, defensively, various, every, many, those,
# Average loss at step 62000: 2.637972
# Average loss at step 64000: 2.848617
# Average loss at step 66000: 2.831816
# Average loss at step 68000: 2.828265
# Average loss at step 70000: 2.786138
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to his: her, their, my, its, your, our, the, derleth,
# Nearest to years: days, months, weeks, times, year, decades, minutes, centuries,
# Nearest to in: during, within, throughout, among, since, with, from, gracious,
# Nearest to and: or, but, while, including, although, consecrations, however, evocative,
# Nearest to also: now, still, often, never, actually, sometimes, always, usually,
# Nearest to most: more, less, some, many, nameless, especially, particularly, very,
# Nearest to it: he, she, there, this, they, today, thus, god,
# Nearest to has: had, have, is, was, having, provides, contains, includes,
# Nearest to i: we, they, you, g, ii, he, remembers, iii,
# Nearest to that: which, what, however, where, eisenman, tal, kuril, who,
# Nearest to for: although, against, while, grained, from, including, after, during,
# Nearest to is: was, has, becomes, are, seems, includes, makes, does,
# Nearest to can: may, could, must, will, should, would, might, cannot,
# Nearest to war: costing, annex, intervarsity, intellectual, avoided, convex, wars, comnenus,
# Nearest to all: both, various, every, some, any, defensively, chauffeur, many,
# Average loss at step 72000: 2.866309
# Average loss at step 74000: 2.845230
# Average loss at step 76000: 2.814791
# Average loss at step 78000: 2.768057
# Average loss at step 80000: 2.746716
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to his: her, their, my, your, its, our, whose, puma,
# Nearest to years: days, months, weeks, minutes, decades, year, times, centuries,
# Nearest to in: during, within, throughout, at, on, near, sneaking, among,
# Nearest to and: or, but, including, although, while, pres, conjuring, tolbert,
# Nearest to also: now, still, often, actually, never, always, typically, sometimes,
# Nearest to most: more, many, some, less, especially, particularly, gianfranco, all,
# Nearest to it: he, she, there, this, they, today, what, cheered,
# Nearest to has: had, have, is, having, provides, was, includes, contains,
# Nearest to i: we, g, ii, you, they, bukharin, bowling, iii,
# Nearest to that: which, what, however, kuril, who, straus, tal, seizing,
# Nearest to for: including, cadets, after, against, haskalah, grained, despite, when,
# Nearest to is: was, has, became, does, refers, becomes, includes, seems,
# Nearest to can: could, may, must, would, will, should, might, cannot,
# Nearest to war: costing, intervarsity, annex, cia, wars, immunization, avoided, intellectual,
# Nearest to all: various, every, many, several, both, some, disinfectant, those,
# Average loss at step 82000: 2.803614
# Average loss at step 84000: 2.779207
# Average loss at step 86000: 2.720049
# Average loss at step 88000: 2.710752
# Average loss at step 90000: 2.758300
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to his: her, their, my, your, its, our, whose, the,
# Nearest to years: days, months, weeks, times, decades, minutes, year, hours,
# Nearest to in: during, within, throughout, among, at, from, of, on,
# Nearest to and: or, including, although, but, however, unending, principled, erne,
# Nearest to also: still, often, now, typically, never, traditionally, always, sometimes,
# Nearest to most: more, less, especially, many, some, particularly, extremely, gianfranco,
# Nearest to it: he, she, this, there, itself, they, today, which,
# Nearest to has: had, have, is, was, having, provides, includes, contains,
# Nearest to i: we, g, ii, you, they, bukharin, iii, gda,
# Nearest to that: which, however, what, bluescreen, where, vit, eisenman, seizing,
# Nearest to for: grained, flavoring, against, without, pendleton, safed, presbyters, including,
# Nearest to is: was, has, are, becomes, requires, seems, refers, be,
# Nearest to can: could, may, should, must, will, would, might, cannot,
# Nearest to war: costing, intellectual, wars, intervarsity, cia, annex, hello, avoided,
# Nearest to all: various, every, both, many, those, any, several, disinfectant,
# Average loss at step 92000: 2.759257
# Average loss at step 94000: 2.667714
# Average loss at step 96000: 2.704049
# Average loss at step 98000: 2.677805
# Average loss at step 100000: 2.701737
# Nearest to eight: seven, nine, six, five, four, zero, three, two,
# Nearest to his: her, their, my, its, your, our, whose, the,
# Nearest to years: days, months, decades, weeks, times, minutes, year, centuries,
# Nearest to in: during, within, throughout, under, on, since, among, until,
# Nearest to and: or, but, although, including, however, contrived, like, etc,
# Nearest to also: never, often, now, still, always, typically, actually, which,
# Nearest to most: more, many, especially, less, some, particularly, dentistry, sanitarium,
# Nearest to it: she, he, there, this, they, itself, today, something,
# Nearest to has: had, have, is, was, having, provides, maintains, produces,
# Nearest to i: we, you, g, ii, iii, they, griswold, ys,
# Nearest to that: which, what, however, where, kuril, seizing, tal, guts,
# Nearest to for: despite, grained, after, flavoring, cadets, including, during, of,
# Nearest to is: was, has, requires, remains, becomes, refers, includes, seems,
# Nearest to can: could, must, may, should, will, would, might, cannot,
# Nearest to war: costing, annex, wars, intervarsity, cia, intellectual, am, avoided,
# Nearest to all: both, various, many, those, every, disinfectant, certain, some,
